# %% [markdown]
# # Spotify Analysis
#     Data analysis project.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks = pd.read_csv('data/tracks.csv')
df_tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
df_tracks.isnull().sum()
# Out:
# id                   0
# name                71
# popularity           0
# duration_ms          0
# explicit             0
# artists              0
# id_artists           0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# dtype: int64

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 586672 entries, 0 to 586671
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                586672 non-null  object
#  1   name              586601 non-null  object
#  2   popularity        586672 non-null  int64
#  3   duration_ms       586672 non-null  int64
#  4   explicit          586672 non-null  int64
#  5   artists           586672 non-null  object
#  6   id_artists        586672 non-null  object
#  7   release_date      586672 non-null  object
#  8   danceability      586672 non-null  float64
#  9   energy            586672 non-null  float64
#  10  key               586672 non-null  int64
#  11  loudness          586672 non-null  float64
#  12  mode              586672 non-null  int64
#  13  speechiness       586672 non-null  float64
#  14  acousticness      586672 non-null  float64
#  15  instrumentalness  586672 non-null  float64
# ...

# %% [markdown]
# ## Find the least popular songs in the spotify dataset

# %%
sorted_df = df_tracks.sort_values('popularity', ascending=True).head(10)
sorted_df
# Out:
#                             id  \
# 546130  181rTRhCcggZPwP2TUcVqm
# 546222  0yOCz3V5KMm8l1T8EFc60i
# 546221  0y48Hhwe52099UqYjegRCO
# 546220  0xCmgtf9ka07hkZg3D6PaV
# 546219  0tBXS3VuCPX7KWUFH2nros
# 546218  0qrKnQtYDVJhKFAXTHYVS9
# 546217  0nqsDxOeKSwEzp3AUQAAqS
# 546216  0kGEdsxVLYjCdfxM9tbezd
# 546215  0bc3PUZurUUXrY7yqoOxjq
# 546214  0Wwm0ruSjYMIiWG0nyAI1F
#
#                                                      name  popularity  \
# 546130       Newspaper Reports On Abner, 20 February 1935           0
# 546222                                             恋は水の上で           0
# 546221                                              私の誕生日           0
# 546220                                エル・チョクロ (EL CHOCLO)           0
# 546219                                           恋は不思議なもの           0
# 546218                         ゆうべはどうしたの (WHATSA MALLA U)           0
# 546217  Screen Director's Playhouse, Music For Million...           0
# ...

# %%
df_tracks.describe().transpose()
# Out:
#                      count           mean            std     min          25%  \
# popularity        586672.0      27.570053      18.370642     0.0      13.0000
# duration_ms       586672.0  230051.167286  126526.087418  3344.0  175093.0000
# explicit          586672.0       0.044086       0.205286     0.0       0.0000
# danceability      586672.0       0.563594       0.166103     0.0       0.4530
# energy            586672.0       0.542036       0.251923     0.0       0.3430
# key               586672.0       5.221603       3.519423     0.0       2.0000
# loudness          586672.0     -10.206067       5.089328   -60.0     -12.8910
# mode              586672.0       0.658797       0.474114     0.0       0.0000
# speechiness       586672.0       0.104864       0.179893     0.0       0.0340
# acousticness      586672.0       0.449863       0.348837     0.0       0.0969
# instrumentalness  586672.0       0.113451       0.266868     0.0       0.0000
# ...

# %% [markdown]
# ## Top Ten Popular Songs With Popularity More Than 90

# %%
most_popular = df_tracks.query('popularity>90', inplace=False).sort_values('popularity', ascending=False)
most_popular[:5]
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
# 92810  5QO79kh1waicV47BqGRL3g                         Save Your Tears
# 92811  6tDDoYIxWvMLTdKpjFkc1B                               telepatía
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
# 92810          97       215627         1
# 92811          97       160191         0
#
#                                             artists  \
# 93802  ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# 93803                            ['Olivia Rodrigo']
# 93804                               ['Masked Wolf']
# 92810                                ['The Weeknd']
# ...

# %%
list_main_columns = ['name', 'popularity', 'artists', 'duration_ms']
most_popular[list_main_columns]
# Out:
#                                                     name  popularity  \
# 93802             Peaches (feat. Daniel Caesar & Giveon)         100
# 93803                                    drivers license          99
# 93804                             Astronaut In The Ocean          98
# 92810                                    Save Your Tears          97
# 92811                                          telepatía          97
# 92813                                    Blinding Lights          96
# 93805                                Leave The Door Open          96
# 92814                                       The Business          95
# 91866                                            Streets          94
# 92816                             Heartbreak Anniversary          94
# 92817                                        WITHOUT YOU          94
# 92819                                            Bandido          94
# 93807  Friday (feat. Mufasa & Hypeman) - Dopamine Re-...          94
# ...

# %% [markdown]
# ## Make the Release Date Column as the Index Column
#
#     Will perform this aciton with the help of the `set_index` function

# %%
df_tracks.index
# Out:
# RangeIndex(start=0, stop=586672, step=1)

# %%
df_tracks[:5]
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
# Setting `release_date` as index of the Dataframe
df_tracks.set_index('release_date', inplace=True)
df_tracks.index = pd.to_datetime(df_tracks.index)

# %%
df_tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# 1922-02-22             6       126903         0              ['Uli']
# 1922-06-01             0        98200         0  ['Fernando Pessoa']
# 1922-03-21             0       181640         0  ['Ignacio Corsini']
# 1922-03-21             0       176907         0  ['Ignacio Corsini']
# 1922-01-01             0       163080         0      ['Dick Haymes']
#
# ...

# %%
df_tracks.index
# Out:
# DatetimeIndex(['1922-02-22', '1922-06-01', '1922-03-21', '1922-03-21',
#                '1922-01-01', '1922-01-01', '1922-01-01', '1922-01-01',
#                '1922-01-01', '1922-03-29',
#                ...
#                '2020-12-20', '2020-12-29', '2020-03-03', '2020-03-20',
#                '2020-02-08', '2020-09-26', '2020-10-21', '2020-09-02',
#                '2021-03-05', '2015-07-01'],
#               dtype='datetime64[ns]', name='release_date', length=586672, freq=None)

# %% [markdown]
# ## Find the Name of the Artist Present in the 18th Row of Dataset.

# %%
# df_tracks[["artists"]].iloc[18]
df_tracks.iloc[18]
# Out:
# id                      0kCB1bDVBC8gWCFcnJyIZc
# name                        Ca C'est Une Chose
# popularity                                   0
# duration_ms                             188000
# explicit                                     0
# artists                     ['Victor Boucher']
# id_artists          ['7vVR02JJYvsEAEPNHQMx0Q']
# danceability                           0.35200
# energy                                 0.33400
# key                                          5
# loudness                             -13.03800
# mode                                         1
# speechiness                            0.05940
# acousticness                           0.99600
# instrumentalness                       0.00746
# liveness                               0.36000
# valence                                0.41400
# tempo                                 76.40300
# time_signature                               4
# Name: 1922-01-01 00:00:00, dtype: object

# %%
victor_artist = df_tracks.artists.iloc[18]
victor_artist_str = "['Victor Boucher']"
df_tracks.query('artists == @victor_artist_str')
# Out:
#                                   id                name  popularity  \
# release_date
# 1922-01-01    0kCB1bDVBC8gWCFcnJyIZc  Ca C'est Une Chose           0
# 1922-01-01    1lia44teZBfbv0PnPkc5dK       Machinalement           0
#
#               duration_ms  explicit             artists  \
# release_date
# 1922-01-01         188000         0  ['Victor Boucher']
# 1922-01-01         145400         0  ['Victor Boucher']
#
#                               id_artists  danceability  energy  key  loudness  \
# release_date
# 1922-01-01    ['7vVR02JJYvsEAEPNHQMx0Q']         0.352   0.334    5   -13.038
# 1922-01-01    ['7vVR02JJYvsEAEPNHQMx0Q']         0.457   0.193    4   -16.816
#
#               mode  speechiness  acousticness  instrumentalness  liveness  \
# release_date
# 1922-01-01       1       0.0594         0.996           0.00746    0.3600
# 1922-01-01       1       0.0655         0.996           0.34800    0.0809
#
#               valence    tempo  time_signature
# release_date
# ...

# %%
## Changes all row values to 1, for columns in variable `list_main_columns`

# df_tracks.loc[:, list_main_columns] = 1
# df_tracks

# %% [markdown]
# ## Find the Top 3 Songs in Most Popular

# %%
most_popular.iloc[0:3]  # or just index [:3] -- 1st to 3rd song (inclusive) is by indexing [0:3]
# Out:
#                            id                                    name  \
# 93802  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon)
# 93803  7lPN2DXiMsVn7XUKtOW1CS                         drivers license
# 93804  3Ofmpyhv5UAQ70mENzB277                  Astronaut In The Ocean
#
#        popularity  duration_ms  explicit  \
# 93802         100       198082         1
# 93803          99       242014         1
# 93804          98       132780         0
#
#                                             artists  \
# 93802  ['Justin Bieber', 'Daniel Caesar', 'Giveon']
# 93803                            ['Olivia Rodrigo']
# 93804                               ['Masked Wolf']
#
#                                               id_artists release_date  \
# 93802  ['1uNFoZAHBGtllmzznpCI3s', '20wkVLutqVOYrc0kxF...   2021-03-19
# 93803                         ['1McMsnEElThX1knmY4oliG']   2021-01-08
# 93804                         ['1uU7g3DNSbsu0QjSEqZtEd']   2021-01-06
#
# ...

# %% [markdown]
# ## Convert the duration of the song from milliseconds to seconds

# %%
# Convertion from ms to secs
df_tracks["duration"] = df_tracks.duration_ms.apply(lambda x: round(x/1000))
# dropping column `duration_ms`
df_tracks.drop("duration_ms", inplace=True, axis=1) 
df_tracks.duration.head()
# Out:
# release_date
# 1922-02-22    127
# 1922-06-01     98
# 1922-03-21    182
# 1922-03-21    177
# 1922-01-01    163
# Name: duration, dtype: int64

# %% [markdown]
# ## Correlation Map
#
# 1. Create visualization: the correlation map
# 2. Drop three unwanted keys, mode and explicit columns
# 3. Apply the pearson correlation method
#
# - Set figure size of correlation map to (14, 6).
# - Use `heatmap()` function to create the correlation map & set `annotation = True` which will write the data value in each cell.
# - Set `fmt = ".1g"` -> string formatting quotes used when adding annotations.
# - `cmap` stands for the colour map.

# %%
corr_df = df_tracks.drop(["key", "mode", "explicit"], axis=1).corr(method="pearson")
plt.figure(figsize=(14,6))
heatmap = sns.heatmap(corr_df, annot=True, fmt=".1g", vmin=-1, vmax=1, center=0, cmap="inferno", linewidths=1, linecolor="black")
heatmap.set_title("Correlation Heatmap Between Variables")
# heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=90)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap Between Variables')

# %% [markdown]
# ## Sample Only 4 Percent of the Whole Dataset

# %%
sample_df = df_tracks.sample(int(.004*len(df_tracks)))
sample_df.head()
# Out:
#                                   id           name  popularity  explicit  \
# release_date
# 1976-10-01    1hkACmNkF1HsDbafEzwYkj  't Is Voorbij           9         0
# 1940-01-01    1xMJ2wEI9rlJwnfODG9Zez   Easy to Love           0         0
# 2003-07-01    7rMp2LdvFkmL5koODZUrJN     Inkarneret          25         0
# 2008-01-01    4WvyEJU1Xc170XtGf7WoYi      Mu koduke          18         0
# 1992-01-01    5g0IODsL7hiPxExwKNjIPo        容易受傷的女人          45         0
#
#                                         artists                  id_artists  \
# release_date
# 1976-10-01               ['Gebroeders Brouwer']  ['6D6SBRwZYa1PpyDIxnbRZv']
# 1940-01-01                   ['Mildred Bailey']  ['0LyTHMstvqKiSoqdnnjqix']
# 2003-07-01                           ['L.O.C.']  ['0VUVvNFIyMeIWguwhhImIc']
# 2008-01-01    ['Ülenurme Laulustuudio Lauljad']  ['5bgdM6eUTIlQWEWQUv0xJU']
# 1992-01-01                        ['Faye Wong']  ['3df3XLKuqTQ6iOSmi0K3Wp']
#
# ...

# %% [markdown]
# Will use `regplot()` function in the seaborn library to draw the regression plot.

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df, y="loudness", x="energy", color="c").set(title="Loudness vs. Energy Correlation")
# Out:
# [Text(0.5, 1.0, 'Loudness vs. Energy Correlation')]

# %% [markdown]
# There is a very high positive correlation between loudness and energy. As energy increases, loudness of the song also increases and similiarly, if the song's loudness decreases, the energy of the track also decreases.

# %% [markdown]
# ## Create a regression plot between popularity and acousticness in the form of a regression line.

# %%
plt.figure(figsize=(10,6))
sns.regplot(data=sample_df, y="popularity", x="acousticness", color="b").set(title = "Popularity vs. Acousticness Correlation")
# Out:
# [Text(0.5, 1.0, 'Popularity vs. Acousticness Correlation')]

# %% [markdown]
# The regression line is in a downward direction, indicating that the as acousticness of the song increases, the popularity decreases. Similarily, as popularity increases, acousticness decreases.

# %%
df_tracks['dates'] = df_tracks.index.get_level_values('release_date')
df_tracks.dates = pd.to_datetime(df_tracks.dates)
years = df_tracks.dates.dt.year

# %% [markdown]
# ## Duration of Songs for each year - Line Graph
#
# With years on the x-axis and duration on the y-axis. We see that the songs from 1920s to 1960s were of shorter duration. After 1960, the duration of the songs started increasing until 2010. From 2010 onwards, the duration again started declining.

# %%
# total_dr = df_tracks.duration
# sns.set_style(style="whitegrid")
# fig_dims=(10,5)
# fig, ax = plt.subplots(figsize=fig_dims)
# fig=sns.lineplot(x=years, y=total_dr, ax=ax).set(title="Year vs. Duration")
# plt.xticks(rotation=60)

# %% [markdown]
# ## Data analysis based on genres of the songs

# %%
df_genre = pd.read_csv("data/SpotifyFeatures.csv")
df_genre.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %% [markdown]
# Here we will:
# - Plot duration of the songs w.r.t different genres using a horizontal barplot

# %%
plt.title("Duration of the Songs in Different Genres")
sns.color_palette("rocket", as_cmap=True)
sns.barplot(y="genre", x="duration_ms", data=df_genre)
plt.xlabel("Duration in milli seconds")
plt.ylabel("Genres")
# Out:
# Text(0, 0.5, 'Genres')

# %% [markdown]
# - Find top five genres by Popularity and plot a barplot for popularity vs genre

# %%
sns.set_style(style="darkgrid")
plt.figure(figsize=(10,5))
famous = df_genre.sort_values("popularity", ascending=False)
sns.barplot(data=famous, y="genre", x="popularity").set(title="Top 5 Genres by Popularity")
# Out:
# [Text(0.5, 1.0, 'Top 5 Genres by Popularity')]

# %%
df_genre.sort_values('popularity',ascending = False)
# Out:
#         genre      artist_name                                track_name  \
# 9027    Dance    Ariana Grande                                   7 rings
# 107804    Pop    Ariana Grande                                   7 rings
# 86951     Rap      Post Malone                                      Wow.
# 107803    Pop      Post Malone                                      Wow.
# 107802    Pop    Ariana Grande  break up with your girlfriend, i'm bored
# ...       ...              ...                                       ...
# 195435  Movie    Sally Dworsky                                Inside Out
# 195434  Movie     Mike Douglas                            September Song
# 195433  Movie      Keith David                       The Christmas Story
# 195432  Movie  Charlton Heston               Chorus: Come And Go With Me
# 0       Movie   Henri Salvador               C'est beau de faire un Show
#
#                       track_id  popularity  acousticness  danceability  \
# ...

# %% [markdown]
# ### The following is the correct analysis.
#
# Use the average of popularity grouped by genre.

# %%
# Top 6 most popular genres
gg = df_genre.groupby('genre').describe()
gg_sorted = gg["popularity"].sort_values("mean", ascending=False)
gg_topsix = gg_sorted.head(6)
gg_topsix
# Out:
#           count       mean        std   min   25%   50%   75%    max
# genre
# Pop      9386.0  66.590667   7.248797   3.0  62.0  66.0  71.0  100.0
# Rap      9232.0  60.533795   8.177226  14.0  55.0  59.0  65.0   99.0
# Rock     9272.0  59.619392   7.474083   0.0  54.0  59.0  64.0   95.0
# Hip-Hop  9295.0  58.423131   8.269761  14.0  52.0  57.0  63.0   98.0
# Dance    8701.0  57.275256  11.208370   0.0  51.0  57.0  64.0  100.0
# Indie    9543.0  54.701561   7.355754   0.0  49.0  54.0  59.0   97.0

# %%
df_genre_sorted = df_genre.groupby('genre').mean().sort_values('popularity', ascending=False)

sns.barplot(x='popularity',
            y="genre", data=df_genre,
            order=df_genre_sorted.index).set(title="Top Genres by Popularity")
# Out:
# [Text(0.5, 1.0, 'Top Genres by Popularity')]

# %%
sns.barplot(x="popularity",
            y="genre", data=df_genre,
            order=df_genre_sorted.index[:5]
            ).set(title="Top 5 Genres by Popularity")
# Out:
# [Text(0.5, 1.0, 'Top 5 Genres by Popularity')]

# %% [markdown]
# ### The following code is wrong.
#
# We cannot analyze the data using the summation of popularity by genre. The data will be bias towards the Indie Genre when deciding fifth place, this is caused by the larger volume of indie music on Spotify compared to Dance. Thus, summing popularity by genre will result in Indie being place higher, just by the greater count of songs in that genre.
#
# As we see in the table above, Indie has 9543 songs while Dance has 8701. Indie has 842 more songs than the Dance genre.
#
# We should be taking the average of popularity for each genre, in order to get the correct result of this anaylsis.

# %%
# This is WRONG in analyzing the top 5 most popular genres.
famous[['genre', 'popularity']].groupby(by="genre").sum().sort_values("popularity", ascending=False).head(6)
# Out:
#                   popularity
# genre
# Pop                   625020
# Rap                   558848
# Rock                  552791
# Hip-Hop               543043
# Indie                 522017
# Children’s Music      511226
